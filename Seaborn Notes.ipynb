# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods. The primary goal of EDA is to see what the data can tell us beyond the formal modeling or hypothesis testing task.
#
# **Uses:**
# - **Understanding Data:** EDA helps in understanding the underlying structure of the data.
# - **Identifying Patterns:** It assists in identifying patterns, anomalies, and trends within the data.
# - **Detecting Outliers:** It helps in detecting outliers and errors in the data.
# - **Hypothesis Formation:** EDA aids in formulating hypotheses for further analysis.
# - **Data Cleaning:** It can be used to identify missing values, duplicates, and other data issues that need to be addressed.
# - **Feature Selection:** EDA helps in selecting the most important features for modeling.

# %% [markdown]
# ## Seaborn
#
# Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# **Uses:**
# - **Statistical Plots:** Seaborn is used for creating a variety of statistical plots such as bar plots, violin plots, box plots, and scatter plots.
# - **Complex Visualizations:** It simplifies the process of creating complex visualizations like heatmaps, pair plots, and facet grids.
# - **Aesthetic Customization:** Seaborn comes with built-in themes and color palettes to make visualizations more attractive and easier to interpret.

# %% [markdown]
# **Benefits in EDA:**
# - **Simplifies Plotting:** Seaborn simplifies the creation of complex plots, making it easier to explore and understand the data.
# - **Integration with Pandas:** Seaborn works well with Pandas DataFrames, making it easier to visualize data directly from data frames.
# - **Statistical Insights:** The library provides tools for visualizing the distribution of data and relationships between variables, which are essential for EDA.
# - **Customization:** It allows for easy customization of plots, which can help in highlighting specific insights and findings during EDA.
#
# Using Seaborn during EDA can enhance the effectiveness of the analysis by providing clear, concise, and visually appealing graphics that can reveal underlying patterns and insights in the data.

# %% [markdown]
# ## Installing Seaborn

# %%
#pip install seaborn

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import statsmodels.api as sm 
import pylab as py 
from statsmodels.graphics.mosaicplot import mosaic

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# - Histogram: `sns.histplot()`
# - Bar chart: `sns.countplot()` in Seaborn
# - Pie chart: `pyplot.pie()` in Matplotlib
# - Line chart: `sns.lineplot()` in Seaborn
# - Box plot: `sns.boxplot()` in Seaborn
# - Violin plot: `sns.violinplot()` in Seaborn
# - Kernel density estimation (KDE) plot: `sns.kdeplot()` in Seaborn
# - Rug plot: `sns.rugplot()` in Seaborn
# - Swarm plot: `sns.swarmplot()` in Seaborn
# - Density plot: `sns.kdeplot()` in Seaborn
# - Q-Q plot: `sns.qqplot()` in Seaborn
# - Empirical cumulative distribution function (ECDF) plot: `sns.ecdfplot()` in Seaborn

# %% [markdown]
# ## Bivariate Analysis
# ### Numerical-Numerical Analysis
# - Scatter plot: `sns.scatterplot()` function in Seaborn.
#
# - Line plot: `sns.lineplot()` function in Seaborn.
#
# - Hexbin plot: `sns.jointplot()` function with kind=hex in Seaborn.
#
# - Box plot: `sns.boxplot()` function in Seaborn.
#
# - Violin plot: `sns.violinplot()` function in Seaborn.
#
# - Heatmap: `sns.heatmap()` function in Seaborn.
#
# - Jointplot: `sns.jointplot()` function in Seaborn.
#
# ### Numerical-Categorical Analysis
# - Bar chart: `sns.barplot()` function in Seaborn.
#
# - Box plot: `sns.boxplot()` function in Seaborn.
#
# - Violin plot: `sns.violinplot()` function in Seaborn.
#
# - Point plot: `sns.pointplot()` function in Seaborn.
#
# - Swarm plot: `sns.swarmplot()` function in Seaborn.
#
# - Factor plot: You can use it with multiple ways, `boxplot`, `violinplot`, etc.
#
# ### Categorical-Categorical Analysis
# - Bar chart: `sns.countplot()` function in Seaborn.
#
# - Stacked bar chart: `sns.barplot()` function in Seaborn with hue parameter.
#
# - Mosaic plot: It can be created using the `mosaic()` function in the mosaicplot library.
#
# - Categorical scatter plot: `sns.scatterplot()` function in seaborn.
#
# - Categorical heatmap: `sns.heatmap()` function in Seaborn with categorical parameter.
#
# - Categorical boxplot: It can be created using the `sns.boxplot()` function in Seaborn with hue parameter.

# %%
df = pd.read_csv("Datasets/tips.csv")
df1 = pd.read_csv("Datasets/batsman_2017_record.csv")
df2 = px.data.gapminder()
pakistan = df2[df2['country'] == 'Pakistan']
pakistan
# Out:
#        country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 1164  Pakistan      Asia  1952   43.436   41346560   684.597144       PAK
# 1165  Pakistan      Asia  1957   45.557   46679944   747.083529       PAK
# 1166  Pakistan      Asia  1962   47.670   53100671   803.342742       PAK
# 1167  Pakistan      Asia  1967   49.800   60641899   942.408259       PAK
# 1168  Pakistan      Asia  1972   51.929   69325921  1049.938981       PAK
# 1169  Pakistan      Asia  1977   54.043   78152686  1175.921193       PAK
# 1170  Pakistan      Asia  1982   56.158   91462088  1443.429832       PAK
# 1171  Pakistan      Asia  1987   58.245  105186881  1704.686583       PAK
# 1172  Pakistan      Asia  1992   60.838  120065004  1971.829464       PAK
# 1173  Pakistan      Asia  1997   61.818  135564834  2049.350521       PAK
# 1174  Pakistan      Asia  2002   63.610  153403524  2092.712441       PAK
# 1175  Pakistan      Asia  2007   65.483  169270617  2605.947580       PAK
#
# ...

# %% [markdown]
# ### Histogram
# A histogram is a classic visualization tool that represents the distribution variables by counting the number of observations that fall within discrete bins.
# - `histplot()` is axes level function and `displot()` is figure level function.

# %%
sns.histplot(data=df,x='total_bill',bins=20,color='red')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df,x='total_bill',bins=20,fill=False,color='yellow')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df,x='total_bill',bins=20,hue='sex')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df,x='total_bill',bins=20,hue='sex',element='step')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### Figure Level Function for hist plot

# %%
sns.displot(data=df,x='total_bill',bins=20,hue='sex',element='step',kind='hist')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Count Plot
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Figure Level Function for count plot

# %%
sns.catplot(data=df,x='sex',hue='day',kind='count')

# %% [markdown]
# ## Pie Chart
# A Pie Chart is a circular statistical plot that can display only one series of data. The area of the chart is the total percentage of the given data.

# %%
plt.pie(df1['2017'],labels=df1['batsman'],autopct="%0.1f%%")
plt.show()

# %%
plt.pie(df1['2017'],labels=df1['batsman'],autopct="%0.1f%%",shadow=True)
plt.show()

# %%
plt.pie(df1['2017'],labels=df1['batsman'],autopct="%0.1f%%",colors=['red','blue','purple','yellow','green'])
plt.show()

# %%
plt.pie(df1['2017'],labels=df1['batsman'],autopct="%0.1f%%",explode=[0,0,0.1,0,0])
plt.show()

# %% [markdown]
# ### Line Plot
# Line plots are generally used to show how information changes over time. Generally, the data in the x-axis represents a continuous variable (such as dates) and is sorted in a meaningful way.

# %%
sns.lineplot(data=pakistan,x='year',y='lifeExp',color='red')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='lifeExp'>

# %% [markdown]
# ### Figure Level Function for line plot

# %%
sns.relplot(data=pakistan,x='year',y='lifeExp',kind='line',color='red')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### How to set background color of Graph

# %%
plt.axes().set_facecolor('yellow')
ax = sns.lineplot(data=pakistan,x='year',y='lifeExp',color='purple')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### How to set title, xlabel and ylabels of Graph

# %%
ax = sns.lineplot(data=pakistan,x='year',y='lifeExp',color='purple')
ax.set(title="Life Expectancy",xlabel = "Year",ylabel="Life Expectancy")
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# [Text(0.5, 1.0, 'Life Expectancy'),
#  Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Life Expectancy')]

# %% [markdown]
# ### More Lines on a Single Graph

# %%
inpac = df2[df2['country'].isin(['Pakistan','India','China'])]
inpac
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
ax = sns.relplot(data=inpac,x='year',y='lifeExp',hue='country',kind='line')
ax.set(title="Life Expectation Analysis",xlabel='Year',ylabel='Life Expectancy')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Box Plot
# A box plot helps to maintain the distribution of quantitative data in such a way that it facilitates the comparisons between variables or across levels of a categorical variable. The main body of the box plot showing the quartiles and the median’s confidence intervals if enabled. The medians have horizontal lines at the median of each box and while whiskers have the vertical lines extending to the most extreme, non-outlier data points and caps are the horizontal lines at the ends of the whiskers.

# %%
sns.boxplot(data=df,y='total_bill',x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Figure level Function for box plot

# %%
sns.catplot(data=df,y='total_bill',x='day',kind='box')

# %% [markdown]
# ### Violin Plot
# A violin plot plays a similar role as a box-and-whisker plot. It shows the distribution of data points after grouping by one (or more) variables. Unlike a box plot, each violin is drawn using a kernel density estimate of the underlying distribution.

# %%
sns.violinplot(data=df,y='total_bill',x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Figure level function for violin plot

# %%
sns.catplot(data=df,y='total_bill',x='day',kind='violin')

# %%
sns.catplot(data=df,y='total_bill',x='day',hue='sex',kind='violin',split=True)

# %% [markdown]
# ### KDE plot
# Kernel Density Estimate (KDE) plot, a visualization technique that offers a detailed view of the probability density of continuous variables.

# %%
sns.kdeplot(data=df,x='total_bill')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='total_bill',hue='sex')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Figure Level Function for kde plot

# %%
sns.displot(data=df,x='total_bill',fill=True,kind='kde')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Rug Plot
# Rug plots are valuable tools to visualize how datasets are distributed, allowing you to gain strong insight into your data. In this tutorial, you’ll learn about the different parameters and options of the Seaborn rugplot function.

# %%
sns.rugplot(data=df,x='total_bill')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ### It is mostly used with some other graph

# %%
sns.kdeplot(data=df,x="total_bill")
sns.rugplot(data=df,x="total_bill")
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Swarm Plot
# Swarm plots are similar to strip plots, however they add spread to the data points. Similar to strip plots, they allow you to better understand the distribution of data along concentrated areas. However, they add even more dimension than strip plots, making it easier to see data points without overlap.

# %%
sns.swarmplot(data=df,x='day',y='total_bill')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=df,x='day',y='total_bill',hue='day')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=df,x='day',y='total_bill',hue='day',kind='swarm')
plt.legend()
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Q-Q plot
# When the quantiles of two variables are plotted against each other, then the plot obtained is known as quantile – quantile plot or qqplot. This plot provides a summary of whether the distributions of two variables are similar or not with respect to the locations.

# %%
sm.qqplot(df['total_bill'])
py.show()

# %%
sm.qqplot(df['total_bill'],line='45')
py.show()

# %% [markdown]
# ### ECDF plot
# An ECDF represents the proportion or count of observations falling below each unique value in a dataset. Compared to a histogram or density plot, it has the advantage that each observation is visualized directly, meaning that there are no binning or smoothing parameters that need to be adjusted.

# %%
sns.ecdfplot(data=df,x='total_bill',hue='sex')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Proportion'>

# %%
sns.displot(data=df,x='total_bill',hue='sex',kind='ecdf')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Scatter Plot
# Scatterplot can be used with several semantic groupings which can help to understand well in a graph. They can plot two-dimensional graphics that can be enhanced by mapping up to three additional variables while using the semantics of hue, size, and style parameters. All the parameter control visual semantic which are used to identify the different subsets.

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',color='red')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
ax = sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='time',size='size')
ax.set(title='Resturant Analysis',xlabel="Total Bill",ylabel="Tip")
# Out:
# [Text(0.5, 1.0, 'Resturant Analysis'),
#  Text(0.5, 0, 'Total Bill'),
#  Text(0, 0.5, 'Tip')]

# %% [markdown]
# ### Figure Level Function for Scatter plot

# %%
ax = sns.relplot(data=df,x='total_bill',y='tip',hue='sex',style='time',size='size',kind='scatter')
ax.set(title='Resturant Analysis',xlabel="Total Bill",ylabel="Tip")

# %% [markdown]
# ### Hexbin Plot
# Hexbin plots take in lists of X and Y values (and an optional list of Z values) and returns what looks somewhat similar to a scatter plot, but where the entire graphing space has been divided into hexagons (like a honeycomb) and all points have been grouped into their respective hexagonal regions with a color gradient indicating the density (or mean Z values) of each hexagonal area.

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='hex')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Joint Plot
# Draw a plot of two variables with bivariate and univariate graphs. This function provides a convenient interface to the ‘JointGrid’ class, with several canned plot kinds.

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='hex')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='scatter')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='kde')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='reg')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='hist')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## HeatMap
# Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.

# %%
hm = pd.read_csv("Datasets/sixes_heatmap.csv")
hm
# Out:
#     overs      1      2      3      4      5      6
# 0       1    9.0   17.0   31.0   39.0   33.0   27.0
# 1       2   31.0   40.0   49.0   56.0   58.0   54.0
# 2       3   75.0   61.0   69.0   72.0   58.0   76.0
# 3       4   60.0   73.0   74.0  103.0   74.0   70.0
# 4       5   71.0   76.0  111.0   80.0   81.0   71.0
# 5       6   77.0  101.0   62.0   86.0   78.0   79.0
# 6       7   34.0   56.0   48.0   59.0   63.0   38.0
# 7       8   59.0   62.0   73.0   68.0   69.0   56.0
# 8       9   86.0   82.0   79.0   81.0   73.0   52.0
# 9      10   54.0   61.0   85.0   61.0   73.0   67.0
# 10     11   82.0   92.0   83.0   69.0   72.0   69.0
# 11     12   91.0   72.0   87.0   79.0   87.0   70.0
# 12     13   87.0  108.0   79.0  100.0  100.0   84.0
# 13     14  100.0  101.0   99.0   97.0   89.0   87.0
# 14     15   90.0  124.0  102.0  100.0   86.0  106.0
# 15     16  101.0  120.0  128.0  120.0  113.0   95.0
# 16     17  106.0  115.0  108.0  100.0  120.0  100.0
# ...

# %%
sns.heatmap(data=hm)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data=hm,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data=hm,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Plot
# A bar plot represents an aggregate or statistical estimate for a numeric variable with the height of each rectangle and indicates the uncertainty around that estimate using an error bar. Bar

# %%
br = pd.read_csv("Datasets/batsman_2017_record.csv")
br
# Out:
#           batsman  2017
# 0  AB de Villiers   216
# 1       DA Warner   641
# 2        MS Dhoni   290
# 3       RG Sharma   333
# 4         V Kohli   308

# %%
sns.barplot(data=br,x='batsman',y='2017')
# Out:
# <Axes: xlabel='batsman', ylabel='2017'>

# %%
sns.barplot(data=df,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Mosaic Plot
# Mosaic Plot is a graphical method for visualizing data from two or more Qualitative data. It’s also called crosstabs or two-way table and it’s used to summarize the relationship among several categorical variables. The Mosaic Plot is based on conditional probabilities.

# %%
data = {'John': 7, 'Joe': 10, 'James': 5, 'Kate': 3}
mosaic(data, title='Basic mosaic plot')
plt.show()

# %% [markdown]
# ## Facet Grid / Faceting

# %%
sns.relplot(data=df,x='total_bill',y='tip',kind='scatter',row='sex',col='smoker',hue='sex',palette=['red','blue'])

# %%
sns.relplot(data=df2,x='lifeExp',y='gdpPercap',col='year',kind='scatter')

# %%
sns.relplot(data=df2,x='lifeExp',y='gdpPercap',col='year',kind='scatter',col_wrap=3)

# %%
sns.catplot(data=df,x='sex',y='total_bill',kind='box',col='smoker',row='time')

# %% [markdown]
# ## Pair Grid

# %%
sns.pairplot(iris)
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(iris,hue='species')
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
g = sns.PairGrid(data=iris,hue='species')
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.kdeplot,fill=True)
g.map_offdiag(sns.scatterplot)
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
g = sns.PairGrid(data=iris,hue='species',vars=['sepal_length','sepal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)
# Out:
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\haide\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
